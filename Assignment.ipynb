# %% [markdown]
# # Phase 1 Project
#
# ## Introduction
#
# Congratulations on completing phase 1! In this notebook, you will complete a final project that applies your python and visualization skills to real word business data.
#
# ## Objectives
# In this project, you will...
# - Read in data that has been stored as a `json` file.
# - Describe how the data is structured.
# - Use Python to filter a nested data structure
# - Define python functions
# - Calculate descriptive statistics
# - Visualize data via matplotlib
#
#
# # Task: Compare New York Pizza Restaurants with Above Average and Below Average Ratings
# ![Pizza gif](https://media.giphy.com/media/eK1eFdpj5kMWqZ9bLJ/giphy.gif?cid=ecf05e47rkbp48nwz3za6dloo8xfwzueu0rx2vklguo7xyhu&rid=giphy.gif&ct=g)
#
# ## Business Understanding
#
# A client at your analytics firm is considering opening a pizza restaurant in New York City.
#
# They have asked you to develop a business intelligence report to fact check the following claims:
# 1. Your client wants to ensure they have an above average Yelp rating. They have previously owned restuarants in other cities, where a `3` was the average. They would like to know if that holds true in New York City.
# 1. Your client has noticed that restaurants on yelp with a high review count seem to be quite successful. They have decided to focus on maximizing their review count which they believe will allow them to have an above average overall review.
# 1. After looking at a few restaurants on Yelp, your client believes that most above average restaurants have a price point of `$$`. They are considering increasing their prices from `$` to `$$` to match the majority of above average restaurants, and would like you to find the most common price point for above average restaurants in New York City.
# 1. In terms of location they have been told that above average restaurants are usually further east and below average are usually further west, but that the biggest difference is whether the restaurant is on the north or south side. They would like you to determine if the data supports this claim.
# 1. They believe that the `10012` zipcode in New York City is the best place to open a restaurant. They wish to open a restaurant in close proximity to other highly rated restaurants, and they believe `10012` has the most in NYC.
#
#
#
# The primary purpose of this analysis is _descriptive_, meaning your analysis should report calculated statistics such as `counts` and `mean`, and should be focused on providing a simple, factual, understanding of the data.
#
#
# ## Data Understanding
#
# You have been provided a Yelp dataset containing information about restaurants in New York City. The data is named `pizza_businesses.json` and is stored in the current working directory. You will need to load in this dataset, inspect how the data is structured, and use the provided information to fact check your client's claims.

# %% [markdown]
# ## Load the data
#
# A dataset containing information about New York pizza restaurants is stored in this notebook's repository with the name `pizza_businesses.json`.
#
# In the cell below, load the json data into a python dictionary.

# %%
# Import the json python package
import json
# Load in the data
with open("pizza_businesses.json") as f:
    pizza_businesses_data = json.load(f)
pizza_businesses_data
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 3976,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129664100',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2354,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+17185966700',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': 'Rubirosa',
#   'review_count': 2438,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129650500',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6189,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129417994',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': 'Lucali',
#   'review_count': 1709,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '575 Henry St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#   'transactions': ['delivery'],
#   'phone': '+17188584086',
#   'latitude': 40.6818,
#   'longitude': -74.00024},
#  {'name': "Roberta's",
#   'review_count': 3004,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184171118',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': "Joe's Pizza",
#   'review_count': 2673,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '7 Carmine St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7 Carmine St', 'New York, NY 10014']},
#   'transactions': ['delivery'],
#   'phone': '+12123661182',
#   'latitude': 40.73055520355198,
#   'longitude': -74.00211632377929},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 596,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery'],
#   'phone': '+17185990002',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': "Joe's Pizza",
#   'review_count': 947,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '150 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 E 14th St', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123889474',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4683,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17188584300',
#   'latitude': 40.702583,
#   'longitude': -73.9932413},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2153,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '278 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122431680',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Scarr's Pizza",
#   'review_count': 500,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '22 Orchard St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['22 Orchard St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123343481',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 154,
#   'rating': 5.0,
#   'price': '\\$\\$',
#   'location': {'address1': '279 71st St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['279 71st St', 'Brooklyn, NY 11209']},
#   'transactions': ['pickup'],
#   'phone': '+17182387100',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3652,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1424 Ave J',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11230',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182581367',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': "Mimi's Pizza",
#   'review_count': 67,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '217 E 86th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['217 E 86th St', 'New York, NY 10028']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468612518',
#   'latitude': 40.778638,
#   'longitude': -73.952895},
#  {'name': "Paulie Gee's",
#   'review_count': 1285,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery'],
#   'phone': '+13479873747',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': "Roberta's",
#   'review_count': 38,
#   'rating': 4.0,
#   'price': 'Unknown',
#   'location': {'address1': '6 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6 Grand St', 'Brooklyn, NY 11249']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182782400',
#   'latitude': 40.71618788546057,
#   'longitude': -73.96651754323669},
#  {'name': 'East Village Pizza',
#   'review_count': 382,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '145 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['145 1st Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125294545',
#   'latitude': 40.728199,
#   'longitude': -73.985182},
#  {'name': 'Bleecker Street Pizza',
#   'review_count': 2454,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '69 7th Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129244466',
#   'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137},
#  {'name': "Joe's Pizza",
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183882216',
#   'latitude': 40.71691,
#   'longitude': -73.958987},
#  {'name': 'Brunetti Pizza',
#   'review_count': 310,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '626 Hudson St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['626 Hudson St', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122555699',
#   'latitude': 40.73829,
#   'longitude': -74.0054},
#  {'name': "Lil Frankie's",
#   'review_count': 1228,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '19 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 1st Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124204900',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': 'L & B Spumoni Gardens',
#   'review_count': 4045,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '2725 86th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11223',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184491230',
#   'latitude': 40.594715,
#   'longitude': -73.981316},
#  {'name': 'Marta',
#   'review_count': 907,
#   'rating': 4.0,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '29 E 29th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['29 E 29th St', 'New York, NY 10016']},
#   'transactions': ['delivery'],
#   'phone': '+12126513800',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': 'Koronet Pizza',
#   'review_count': 42,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '1110 Lexington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10075',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1110 Lexington Ave', 'New York, NY 10075']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16467670424',
#   'latitude': 40.77408,
#   'longitude': -73.95969},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2104,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125948939',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': "Joe's Pizza",
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '124 Fulton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['124 Fulton St', 'New York, NY 10038']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122670860',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': "Dellarocco's",
#   'review_count': 299,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '214 Hicks St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17188581010',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': 'Front Street Pizza',
#   'review_count': 389,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '80 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17188753700',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 255,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '326 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['delivery'],
#   'phone': '+17187832430',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': 'Olio e Piú',
#   'review_count': 2748,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '3 Greenwich Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York City',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Greenwich Ave', 'New York City, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122436546',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': 'Table 87 - Brooklyn Heights',
#   'review_count': 299,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '87 Atlantic Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['87 Atlantic Ave', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17187979300',
#   'latitude': 40.691219329834,
#   'longitude': -73.9973449707031},
#  {'name': 'Gelso & Grand',
#   'review_count': 1080,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '186 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['186 Grand St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122261600',
#   'latitude': 40.7194089547259,
#   'longitude': -73.9973777877722},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 562,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '450 Dean St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17186222268',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 473,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '358 Graham Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17187829659',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': 'Razza Pizza Artigianale',
#   'review_count': 968,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '275 Grove St',
#    'address2': '',
#    'address3': '',
#    'city': 'Jersey City',
#    'zip_code': '07302',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['275 Grove St', 'Jersey City, NJ 07302']},
#   'transactions': ['delivery'],
#   'phone': '+12013569348',
#   'latitude': 40.7177490485075,
#   'longitude': -74.0441924355125},
#  {'name': 'My Pie',
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '166 West 72nd St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['166 West 72nd St', 'New York, NY 10023']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127877200',
#   'latitude': 40.77823,
#   'longitude': -73.98117},
#  {'name': 'IL Brigante',
#   'review_count': 428,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '214 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Front St', 'New York, NY 10038']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122850222',
#   'latitude': 40.707492,
#   'longitude': -74.002571},
#  {'name': "Joe's Pizza",
#   'review_count': 1273,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16465594878',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': 'Village Square Pizza',
#   'review_count': 192,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '147 Ave A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['147 Ave A', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19176757709',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Unregular Pizza',
#   'review_count': 62,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '135 4th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['135 4th Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16466094699',
#   'latitude': 40.73398,
#   'longitude': -73.98961},
#  {'name': "Totonno's",
#   'review_count': 810,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1524 Neptune Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11224',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1524 Neptune Ave', 'Brooklyn, NY 11224']},
#   'transactions': ['pickup'],
#   'phone': '+17183728606',
#   'latitude': 40.578913225666966,
#   'longitude': -73.98383392883555},
#  {'name': 'La Nonna Krispy Krust Pizza',
#   'review_count': 58,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '175 Kent Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['175 Kent Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13473842100',
#   'latitude': 40.717953,
#   'longitude': -73.9637027},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4010,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '321 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['321 E 14th St', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122282004',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': 'Piz-zetta',
#   'review_count': 303,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '90 Livingston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184227878',
#   'latitude': 40.6912834070746,
#   'longitude': -73.9906029201042},
#  {'name': 'Norma',
#   'review_count': 476,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '438 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['438 3rd Ave', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128890600',
#   'latitude': 40.743553,
#   'longitude': -73.980026},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 241,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '110 Franklin St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery'],
#   'phone': '',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': 'NYC Pizza Kitchen',
#   'review_count': 4,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '390 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['390 3rd Ave', 'New York, NY 10016']},
#   'transactions': [],
#   'phone': '+12127299497',
#   'latitude': 40.741947306680636,
#   'longitude': -73.98095156997442},
#  {'name': 'Leuca',
#   'review_count': 346,
#   'rating': 4.0,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '111 N 12th St',
#    'address2': '',
#    'address3': 'The William Vale Hotel',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['111 N 12th St',
#     'The William Vale Hotel',
#     'Brooklyn, NY 11249']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': 'Bellucci Pizza',
#   'review_count': 117,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '29-04 30th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11102',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['29-04 30th Ave', 'Astoria, NY 11102']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17189711074',
#   'latitude': 40.76772937223715,
#   'longitude': -73.9234633428848},
#  {'name': 'Song E Napule',
#   'review_count': 556,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '146 W Houston St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['146 W Houston St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125331242',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': 'Il Porto Ristorante',
#   'review_count': 342,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '37 Washington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37 Washington Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17186240954',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 212,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '345 E 12th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['345 E 12th St', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16469834007',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Emily - West Village',
#   'review_count': 769,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '35 Downing St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35 Downing St', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19179356434',
#   'latitude': 40.729330068469,
#   'longitude': -74.0038400073579},
#  {'name': "Patrizia's Pizza and Pasta",
#   'review_count': 663,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '462-466 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['462-466 2nd Ave', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125979999',
#   'latitude': 40.7398415,
#   'longitude': -73.9792862},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 154,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '432 Union Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13479161062',
#   'latitude': 40.71338,
#   'longitude': -73.95136},
#  {'name': "Adrienne's Pizzabar",
#   'review_count': 1711,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '54 Stone St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['54 Stone St', 'New York, NY 10004']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122483838',
#   'latitude': 40.7043362,
#   'longitude': -74.0101733},
#  {'name': 'Emmy Squared - Brooklyn',
#   'review_count': 672,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '364 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['364 Grand St', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183604535',
#   'latitude': 40.712168,
#   'longitude': -73.955707},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 797,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '690 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123171850',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Mario’s Pizza',
#   'review_count': 11,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '940 Manhattan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['940 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183492700',
#   'latitude': 40.731392,
#   'longitude': -73.954136},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 657,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '298 Atlantic Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['298 Atlantic Ave', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+17188528758',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Baker's Pizza",
#   'review_count': 238,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '201 Avenue A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['201 Avenue A', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127777477',
#   'latitude': 40.72942181645356,
#   'longitude': -73.98127671518847},
#  {'name': "Zazzy's Pizza",
#   'review_count': 39,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '75 Greenwich Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['75 Greenwich Ave', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125420226',
#   'latitude': 40.736699,
#   'longitude': -74.001447},
#  {'name': 'Upside Pizza',
#   'review_count': 27,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '51 Spring St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['51 Spring St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.722115,
#   'longitude': -73.996407},
#  {'name': 'Barano',
#   'review_count': 281,
#   'rating': 4.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '26 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26 Broadway', 'Brooklyn, NY 11249']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13479874500',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': 'Deninos Pizzeria & Tavern',
#   'review_count': 780,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '524 Port Richmond Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10302',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['524 Port Richmond Ave', 'Staten Island, NY 10302']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184429401',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': 'Salsa Pizzeria',
#   'review_count': 7,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '40 Clifford Pl',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['40 Clifford Pl', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13475424680',
#   'latitude': 40.7269007,
#   'longitude': -73.9554019},
#  {'name': 'Adoro Lei',
#   'review_count': 316,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '287 Hudson St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['287 Hudson St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16466665096',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 187,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '90-92 Gansevoort St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90-92 Gansevoort St', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124622703',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Nolita Pizza',
#   'review_count': 91,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '68 Kenmare St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['68 Kenmare St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468959131',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': "Manero's Pizza",
#   'review_count': 59,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '113 Mulberry St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['113 Mulberry St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.717593,
#   'longitude': -73.998396},
#  {'name': 'Marinara Pizza',
#   'review_count': 287,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '1376 Lexington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1376 Lexington Ave', 'New York, NY 10128']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16465595100',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': "Ace's Pizza",
#   'review_count': 50,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery'],
#   'phone': '+13477254366',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': "MAMA'S TOO!",
#   'review_count': 460,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '2750 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2750 Broadway', 'New York, NY 10025']},
#   'transactions': ['delivery'],
#   'phone': '+12125107256',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'Rome To Brooklyn Pizza',
#   'review_count': 84,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'New York, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182693239',
#   'latitude': 40.71187,
#   'longitude': -73.94283},
#  {'name': 'Burrata Pizza',
#   'review_count': 4,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '221 Ave A',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['221 Ave A', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.7302,
#   'longitude': -73.98069},
#  {'name': 'Piccolo Trattoria',
#   'review_count': 95,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '455 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10044',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['455 Main St', 'New York, NY 10044']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127532300',
#   'latitude': 40.7591676767848,
#   'longitude': -73.9525466887989},
#  {'name': 'Rosemary’s',
#   'review_count': 65,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '350 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['350 1st Ave', 'New York, NY 10010']},
#   'transactions': [],
#   'phone': '+16468685335',
#   'latitude': 40.73512,
#   'longitude': -73.97965},
#  {'name': "Nonna's Pizza",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '12 W 18th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['12 W 18th St', 'New York, NY 10011']},
#   'transactions': ['delivery'],
#   'phone': '+12122060500',
#   'latitude': 40.73891,
#   'longitude': -73.99298},
#  {'name': 'Champion Pizza',
#   'review_count': 367,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '17 Cleveland Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122263777',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': 'Marinara Pizza',
#   'review_count': 45,
#   'rating': 4.0,
#   'price': 'Unknown',
#   'location': {'address1': '379 Park Ave S',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['379 Park Ave S', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16466495282',
#   'latitude': 40.74241,
#   'longitude': -73.98452},
#  {'name': 'Sotto 13',
#   'review_count': 938,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '140 W 13th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['140 W 13th St', 'New York, NY 10011']},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'phone': '+12126471001',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'Speedy Romeo',
#   'review_count': 618,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '376 Classon Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['376 Classon Ave', 'Brooklyn, NY 11238']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182300061',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': "Giuseppina's",
#   'review_count': 326,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '691 6th Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['691 6th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['pickup'],
#   'phone': '+17184995052',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 931,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '117 W 57th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['117 W 57th St', 'New York, NY 10019']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123334333',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'Forno Rosso',
#   'review_count': 724,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '327 Gold St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['327 Gold St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184513800',
#   'latitude': 40.694467,
#   'longitude': -73.98293},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 244,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '277 Broome St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['277 Broome St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122264455',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 392,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '59 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['59 5th Ave', 'Brooklyn, NY 11217']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13477631975',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': "Graziella's",
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '232 Vanderbilt Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['232 Vanderbilt Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17187895663',
#   'latitude': 40.6904563903809,
#   'longitude': -73.9696273803711},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 226,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '989 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['989 1st Ave', 'New York, NY 10022']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128888816',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': 'Lazzaro',
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '110 Trinity Place',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Trinity Place', 'New York, NY 10006']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127964499',
#   'latitude': 40.70948,
#   'longitude': -74.012},
#  {'name': "Zazzy's Pizza",
#   'review_count': 41,
#   'rating': 4.0,
#   'price': 'Unknown',
#   'location': {'address1': '173 Orchard St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['173 Orchard St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125420177',
#   'latitude': 40.721617,
#   'longitude': -73.98862},
#  {'name': "Vinnie's Pizzeria",
#   'review_count': 701,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '148 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17187827078',
#   'latitude': 40.7189,
#   'longitude': -73.956843},
#  {'name': 'Coco Pazzeria',
#   'review_count': 16,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '307 Spring St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['307 Spring St', 'New York, NY 10013']},
#   'transactions': ['delivery'],
#   'phone': '+16468501003',
#   'latitude': 40.726166,
#   'longitude': -74.008441},
#  {'name': 'Kesté Pizza & Vino',
#   'review_count': 1448,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '66 Gold S',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['66 Gold S', 'New York, NY 10038']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122431500',
#   'latitude': 40.7093947,
#   'longitude': -74.0048977},
#  {'name': "Proto's Pizza",
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '50 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['50 2nd Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124324044',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Ops',
#   'review_count': 153,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '346 Himrod St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['346 Himrod St', 'Brooklyn, NY 11237']},
#   'transactions': ['delivery'],
#   'phone': '+17183864009',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 562,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '9824 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9824 4th Ave', 'Brooklyn, NY 11209']},
#   'transactions': ['delivery'],
#   'phone': '+13475174868',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': "Lombardi's Pizza",
#   'review_count': 151,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '290 8th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['290 8th Ave', 'New York, NY 10001']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122561973',
#   'latitude': 40.74623,
#   'longitude': -73.9974},
#  {'name': "Ignazio's",
#   'review_count': 550,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '4 Water St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4 Water St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17185222100',
#   'latitude': 40.703137,
#   'longitude': -73.993608},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 149,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '567 Vanderbilt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183999000',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': 'Village Pizza',
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '65 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['65 8th Ave', 'New York, NY 10014']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122434367',
#   'latitude': 40.73927,
#   'longitude': -74.00321},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '190 Cypress Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['190 Cypress Ave', 'Brooklyn, NY 11237']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184561833',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': 'Fascati Pizza',
#   'review_count': 246,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '80 Henry St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 Henry St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+17182371278',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': 'Milkflower',
#   'review_count': 688,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '3412 31st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3412 31st Ave', 'Astoria, NY 11106']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182041300',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': "Rosa's Pizza",
#   'review_count': 135,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '374 Metropolitan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['374 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17189632378',
#   'latitude': 40.7139499,
#   'longitude': -73.95563},
#  {'name': 'Sauce',
#   'review_count': 844,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '78 Rivington St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['78 Rivington St', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12124207700',
#   'latitude': 40.7204716,
#   'longitude': -73.9893263},
#  {'name': "Saluggi's",
#   'review_count': 567,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '325 Church St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['325 Church St', 'New York, NY 10013']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122267900',
# ...
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['36A Ralph Ave', 'Brooklyn, NY 11221']},
#   'transactions': ['delivery'],
#   'phone': '+17186221508',
#   'latitude': 40.689116,
#   'longitude': -73.924281},
#  {'name': 'Bricklyn Pizza',
#   'review_count': 22,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '1240 Hancock St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1240 Hancock St', 'Brooklyn, NY 11221']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187585858',
#   'latitude': 40.692363382489,
#   'longitude': -73.9109713956714},
#  {'name': 'Nonna Maria Brick Oven Pizza',
#   'review_count': 5,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '4108 Tonnele Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'North Bergen',
#    'zip_code': '07047',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['4108 Tonnele Ave', 'North Bergen, NJ 07047']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12013301671',
#   'latitude': 40.78235,
#   'longitude': -74.03495},
#  {'name': 'Tartina',
#   'review_count': 286,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1034 Amsterdam Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1034 Amsterdam Ave', 'New York, NY 10025']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16465900577',
#   'latitude': 40.8035073,
#   'longitude': -73.9636591},
#  {'name': "Joey's Pizza",
#   'review_count': 136,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '6907 Grand Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Maspeth',
#    'zip_code': '11378',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6907 Grand Ave', 'Maspeth, NY 11378']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187795880',
#   'latitude': 40.726213,
#   'longitude': -73.895178},
#  {'name': 'Bosino',
#   'review_count': 37,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '201 W 103rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['201 W 103rd St', 'New York, NY 10025']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16467558770',
#   'latitude': 40.798755,
#   'longitude': -73.9673646},
#  {'name': 'Trattoria Napoli',
#   'review_count': 125,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '4525 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Union City',
#    'zip_code': '07087',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['4525 Broadway', 'Union City, NJ 07087']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12017585465',
#   'latitude': 40.77794,
#   'longitude': -74.01825},
#  {'name': "Ciccio's Pizza",
#   'review_count': 119,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '207 Ave U',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11223',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['207 Ave U', 'Brooklyn, NY 11223']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17185686139',
#   'latitude': 40.596872,
#   'longitude': -73.976309},
#  {'name': 'BD PIZZA',
#   'review_count': 20,
#   'rating': 2.5,
#   'price': '\\$',
#   'location': {'address1': '105 Stanton St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['105 Stanton St', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123350803',
#   'latitude': 40.72106,
#   'longitude': -73.98758},
#  {'name': 'Serafina Fabulous Pizza',
#   'review_count': 354,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1022 Madison Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10075',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1022 Madison Ave', 'New York, NY 10075']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127342676',
#   'latitude': 40.7762350782493,
#   'longitude': -73.9623423504256},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 416,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1758 Victory Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10314',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1758 Victory Blvd', 'Staten Island, NY 10314']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17189810887',
#   'latitude': 40.61281,
#   'longitude': -74.12198},
#  {'name': 'NORMA Gastronomia Siciliana',
#   'review_count': 26,
#   'rating': 4.0,
#   'price': 'Unknown',
#   'location': {'address1': '801 9th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['801 9th Ave', 'New York, NY 10019']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12128890600',
#   'latitude': 40.76563298237293,
#   'longitude': -73.98769143895947},
#  {'name': "Leo's Pizza",
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '31-01 36th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['31-01 36th Ave', 'Astoria, NY 11106']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187218700',
#   'latitude': 40.7566866,
#   'longitude': -73.9296278},
#  {'name': 'V & T Pizzeria & Restaurant',
#   'review_count': 357,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1024 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1024 Amsterdam Ave', 'New York, NY 10025']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126631708',
#   'latitude': 40.80334,
#   'longitude': -73.96383},
#  {'name': 'Il Passatore',
#   'review_count': 383,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '14 Bushwick Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['14 Bushwick Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'phone': '+17189633100',
#   'latitude': 40.71431,
#   'longitude': -73.94217},
#  {'name': 'Brothers Pizza',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '647 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['647 4th Ave', 'Brooklyn, NY 11232']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187681700',
#   'latitude': 40.66341,
#   'longitude': -73.99468},
#  {'name': "Gino's Pizza",
#   'review_count': 164,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '8635 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Elmhurst',
#    'zip_code': '11373',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8635 Broadway', 'Elmhurst, NY 11373']},
#   'transactions': [],
#   'phone': '+17186728515',
#   'latitude': 40.7374456,
#   'longitude': -73.8770859},
#  {'name': '99 Cents Fresh Pizza and Deli',
#   'review_count': 12,
#   'rating': 4.0,
#   'price': 'Unknown',
#   'location': {'address1': '876 6th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['876 6th Ave', 'New York, NY 10001']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '',
#   'latitude': 40.7479100037049,
#   'longitude': -73.9890642464161},
#  {'name': 'Villa Meci Pizzeria',
#   'review_count': 71,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '214 Glen Cove Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Glen Cove',
#    'zip_code': '11542',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Glen Cove Ave', 'Glen Cove, NY 11542']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+15168014400',
#   'latitude': 40.8481627306549,
#   'longitude': -73.635030192143},
#  {'name': 'OddFellows Ice Cream Co.',
#   'review_count': 101,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '44 Water St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['44 Water St', 'Brooklyn, NY 11201']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17186835755',
#   'latitude': 40.70325596349647,
#   'longitude': -73.9924016193591},
#  {'name': 'Famous Famiglia Pizzeria',
#   'review_count': 37,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '83 Maiden Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10007',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['83 Maiden Ln', 'New York, NY 10007']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12124523333',
#   'latitude': 40.70745,
#   'longitude': -74.00748},
#  {'name': 'I Love Panzerotti-- East Village',
#   'review_count': 10,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '130 St Marks Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16465967113',
#   'latitude': 40.7266801,
#   'longitude': -73.9835791},
#  {'name': 'Angies Cafe & Pizza',
#   'review_count': 37,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '2559 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2559 3rd Ave', 'Bronx, NY 10451']},
#   'transactions': ['delivery'],
#   'phone': '+17182923606',
#   'latitude': 40.81153,
#   'longitude': -73.92707},
#  {'name': "Nonno's Pizza",
#   'review_count': 139,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '8816 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8816 3rd Ave', 'Brooklyn, NY 11209']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17182386200',
#   'latitude': 40.62167,
#   'longitude': -74.03197},
#  {'name': 'Pizza Plus',
#   'review_count': 248,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '359 7th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['359 7th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187685327',
#   'latitude': 40.66585,
#   'longitude': -73.98211},
#  {'name': "Joe & John's Pizzeria",
#   'review_count': 145,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '5910 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Ridgewood',
#    'zip_code': '11385',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['5910 Myrtle Ave', 'Ridgewood, NY 11385']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184970078',
#   'latitude': 40.7003933525757,
#   'longitude': -73.8993881901177},
#  {'name': 'Shake Shack',
#   'review_count': 367,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Old Fulton St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+13474352676',
#   'latitude': 40.7030601700019,
#   'longitude': -73.994004},
#  {'name': "Johnny's Pizzeria",
#   'review_count': 327,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '30 W Lincoln Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Mount Vernon',
#    'zip_code': '10550',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['30 W Lincoln Ave', 'Mount Vernon, NY 10550']},
#   'transactions': ['delivery'],
#   'phone': '+19146681957',
#   'latitude': 40.917609,
#   'longitude': -73.839425},
#  {'name': 'American Cheez',
#   'review_count': 113,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '444 7th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['444 7th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['delivery'],
#   'phone': '+13477254665',
#   'latitude': 40.66327,
#   'longitude': -73.9848},
#  {'name': 'Lea',
#   'review_count': 338,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1022 Cortelyou Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11218',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1022 Cortelyou Rd', 'Brooklyn, NY 11218']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17189287100',
#   'latitude': 40.63943,
#   'longitude': -73.96801},
#  {'name': "Mama's Pizza and Cafe",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '80-14 Roosevelt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Jackson Heights',
#    'zip_code': '11372',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80-14 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13478480200',
#   'latitude': 40.7474050196804,
#   'longitude': -73.8853297362896},
#  {'name': "Umberto's Pizzeria & Restaurant",
#   'review_count': 790,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '633 Jericho Tpke',
#    'address2': '',
#    'address3': '',
#    'city': 'New Hyde Park',
#    'zip_code': '11040',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['633 Jericho Tpke', 'New Hyde Park, NY 11040']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+15164377698',
#   'latitude': 40.732218,
#   'longitude': -73.68728},
#  {'name': "Rocky Sullivan's",
#   'review_count': 80,
#   'rating': 4.0,
#   'price': '\\$',
#   'location': {'address1': '46 Beard St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['46 Beard St', 'Brooklyn, NY 11231']},
#   'transactions': [],
#   'phone': '+17182468050',
#   'latitude': 40.67315,
#   'longitude': -74.01224},
#  {'name': 'Sweet Talk',
#   'review_count': 247,
#   'rating': 4.0,
#   'price': '\\$\\$',
#   'location': {'address1': '457 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['457 3rd Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184993400',
#   'latitude': 40.6712112426758,
#   'longitude': -73.9909439086914},
#  {'name': 'Bardolino Pizza',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '1505 Lexington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1505 Lexington Ave', 'New York, NY 10029']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16468501706',
#   'latitude': 40.78665,
#   'longitude': -73.95019},
#  {'name': 'Aurora Soho',
#   'review_count': 483,
#   'rating': 4.0,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '510 Broome St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['510 Broome St', 'New York, NY 10013']},
#   'transactions': ['delivery'],
#   'phone': '+12123349020',
#   'latitude': 40.723543,
#   'longitude': -74.003199}]

# %% [markdown]
# ## Describe the data
#
# Now that you've loaded in the dataset, the structure of the data should be inspected.
#
# In the cell below, evaluate
# - The datatype of the overall dataset
# - The datatype of a single observation
# - The number of observations, and then
# - Isolate the first observation in the dataset

# %%
# Find the datatype for the overall dataset
dataset_type = type(pizza_businesses_data)
# Isolate the first observation
first_observation = pizza_businesses_data[0]
#print (first_observation)
# Find the datatype for the first observation
observation_type = type(first_observation)
# How many observations are there
num_observations = len(pizza_businesses_data)
num_observations
# Out:
# 1000

# %% [markdown]
# Run this following cell unchanged to print out descriptive information for the dataset!

# %%
from pprint import pprint

print(f'The dataset is a \033[1m{dataset_type}\033[0m')
print(f'The observations are a \033[1m{observation_type}\033[0m',)
print(f'There are \033[1m{num_observations} observations.\033[0m')
print('\033[1m\nThe first observation:\033[0m')
print('==========================================')
print(first_observation)
print('==========================================')
# Out:
# The dataset is a <class 'list'>
# The observations are a <class 'dict'>
# There are 1000 observations.
#
# The first observation:
# ==========================================
# {'name': 'Prince Street Pizza', 'review_count': 3976, 'rating': 4.5, 'price': '\\$', 'location': {'address1': '27 Prince St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10012', 'country': 'US', 'state': 'NY', 'display_address': ['27 Prince St', 'New York, NY 10012']}, 'transactions': ['delivery', 'pickup'], 'phone': '+12129664100', 'latitude': 40.72308755605564, 'longitude': -73.99453001177575}
# ==========================================

# %% [markdown]
# ## Find the possible rating options.
#
# In the cell below, create a variable called `rating_options` that has a [set datatype](https://realpython.com/python-sets/), and is a unique collection of the possible ratings a restaurant can recieve.

# %%
# Create the `rating_options` variable
rating_options = set()

# Loop over all of the observations in the dataset
for key in pizza_businesses_data:
    
    # Isolate the rating for the restaurant
    rating_available = key['rating']
       # Add the rating to 
    rating_options.add(rating_available)
    # the `rating_options` variable
    
rating_options
# Out:
# {1.0, 2.0, 2.5, 3.0, 3.5, 4.0, 4.5, 5.0}

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(rating_options) == set
assert len(rating_options) == 8
assert list(rating_options)[0] != list(rating_options)[1]

# %% [markdown]
# ## Plot the distribution for ratings
#
# Now that you know what rating options are available, in the cell below plot a histogram showing the distribution of ratings.

# %%
# Import matplotlib's pyplot module
import matplotlib.pyplot as plt
# Create an empty list.
# We will store all ratings in this list
ratings = []

# Loop over every restaurant in the dataset
for key in pizza_businesses_data:

    # Isolate the rating
    rating_available = key['rating']
    # Append the rating to the `ratings` list
    ratings.append(rating_available)
    
# Create a matplotlib subplot
# Plot a histogram of the ratings list
fig, ax = plt.subplots()
ax.hist(ratings, edgecolor ="red")
plt.title("Histogram for Ratings")
# Out:
# Text(0.5, 1.0, 'Histogram for Ratings')

# %% [markdown]
# **Interpret the ratings histogram. How does the visualization relate to your client's claims?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Isolate the restaurants with an above average rating
#
# Now that you have an understanding for what is an average rating, next you will isolate restaurants with above average and below average ratings so you can compare them.
#
# In the cell below, filter out all restaurants that do not have a rating of at least `4.5`.

# %%
# Create an empty list
# You will store restaurants in this list
above_average = []

# Loop over the dataset
for key in pizza_businesses_data:

    # Isolate the rating
    rating_available = key['rating']
    
    # Check if the rating is at least 4.5
    if (rating_available >= 4.5):
        # If the rating is at least 4.5
        # Add the restaurant to the list
        above_average.append(key)

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(above_average) == list
assert type(above_average[0]) == dict
assert len(above_average) == 306

# %% [markdown]
# ## Isolate restaurants with a below average rating
#
# Now repeat the process for below average ratings.
#
# In the cell below, isolate restaurants that have a rating of no more than `3.5`.

# %%
# Create an empty list
# You will store restaurants in this list
below_average = []

# Loop over the restaurants in the dataset
for key in pizza_businesses_data:

    # Isolate the rating
    rating_available = key['rating']
    
    # Check if the rating is no more than 3.5
    # YOUR CODE HERE
    
        # If the rating no more than 3.5
    if (rating_available <= 3.5):
        # Add the restaurant to the list
        below_average.append(key)

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(below_average) == list
assert type(below_average[0]) == dict
assert len(below_average) == 247

# %% [markdown]
# ## Calculate average review counts for both groups
#
# Now that you've isolated above average and below average restaurants, you can calculate the average number of reviews received by both groups.
#
# To do this, you will need to isolate the review counts for both groups, and calculate their average.
#
# The code for isolating the review counts will look very similar to code you have previously written, which is a good sign that a function should be defined!
#
# In the cell below, define a function called `isolate_values` that receives two arguments:
# 1. A list of dictionaries
# 2. A string indicating the key that should be isolated for each dictionary
#
# This function should:
# - Loop over every dictionary in the inputted list
# - Pull out the value assigned to the inputted key
# - Append the value to a new list
# - Return the new list of values

# %%
def isolate_values(dictionaries, key):
    # Create an empty list
    list_of_values= list()
    # for storing data
    # YOUR CODE HERE
    
    # Loop over every dicionary 
    for values in dictionaries:
        
        # Isolate the value of the dictionary with the `key`
        temp_value= values[key]
            
        # Append the value to the list
        list_of_values.append(temp_value)
    
    # Return the list of values
    # YOUR CODE HERE
    return list_of_values

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
from types import FunctionType

assert type(isolate_values) == FunctionType
assert type(isolate_values([{'test': 1}], 'test')) == list
assert len(isolate_values([{'test': 1}], 'test')) == 1
assert len(isolate_values(above_average, 'name')) == len(above_average)
assert isolate_values(above_average, 'name')[-1] == above_average[-1]['name']

# %% [markdown]
# Now use the `isolate_values` function to create a list called `abv_avg_rev_cnts` that contains the review counts for every above average restaurant.

# %%
# Replace None with your code
abv_avg_rev_cnts = isolate_values(dictionaries= above_average,key = "review_count")

# %% [markdown]
# Now use the `isolate_values` function to create a list called `blw_avg_rev_cnts` that contains the review counts for every below average restaurant.

# %%
# Replace None with your code
blw_avg_rev_cnts = isolate_values(dictionaries= below_average,key = "review_count")

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(abv_avg_rev_cnts) == list
assert type(abv_avg_rev_cnts[0]) == int
assert type(blw_avg_rev_cnts) == list
assert type(blw_avg_rev_cnts[0]) == int
assert len(abv_avg_rev_cnts) == len(above_average)
assert len(blw_avg_rev_cnts) == len(below_average)
assert abv_avg_rev_cnts[101] == above_average[101]['review_count']
assert blw_avg_rev_cnts[101] == below_average[101]['review_count']

# %% [markdown]
# Now that you've isolated the review counts for both groups, you can calculate the average review count!
#
# But before you do that, you should inspect the distribution of review counts to make sure `mean` is an appropriate measure of centrality.
#
# In the cell below, we plot a histogram for above average and below average restaurant review counts.

# %%
# Initialize a matplotlib subplot
# with 1 row and 2 columns
fig, ax = plt.subplots(1,2, figsize=(15,6))

# Plot a histogram of below average review countsLoop over the above average restaurants
# YOUR 
# on the first axis
ax[0].hist(blw_avg_rev_cnts)

# Set the title for the first axis
# to "Below Average - Review Counts"
ax[0].set_title("Below Average - Review Counts")

# Plot a histogram of above average review counts
# on the first axis
ax[1].hist(abv_avg_rev_cnts)

# Set the title for the first axis
# to "Above Average - Review Counts"
ax[1].set_title("Above Average - Review Counts");

# %% [markdown]
# **Interpret the above visualizations. What statistic is best suited for these data?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# In the cell below, calculate the average review count for above average and below average restaurants.

# %%
# Import numpy
# YOUR CODE HERE
import numpy
# Replace None with your code
abv_avg_rev_cnt_center = sum(abv_avg_rev_cnts)/len(abv_avg_rev_cnts)
blw_avg_rev_cnt_center = sum(blw_avg_rev_cnts)/len(blw_avg_rev_cnts)

print('Above average review count:', abv_avg_rev_cnt_center)
print('Below average review count:', blw_avg_rev_cnt_center)
# Out:
# Above average review count: 189.3856209150327
# Below average review count: 285.99595141700405

# %% [markdown]
# **Interpret the average review count for both groups. How does this relate to your client's claims?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Count the price option frequency
#
# The `price` variable in the dataset is a string of dollar signs indicating how expensive a restaurant's price point is.
#
# In the cell below, write a for loop that counts how frequently a given price point appears for the `above_average` dataset

# %%
# Create an empty dictionary to store the
# counts for each price point
abv_avg_prices = dict()

# Loop over the above average restaurants
# YOUR CODE HERE
for key in above_average:
    # Isolate the price point for the restuarant
    # YOUR CODE HERE
    price_point=key['price']
    # Check if the price has been added to the dictionary
    # YOUR CODE HERE
    if price_point in abv_avg_prices:
        abv_avg_prices[price_point]+=1
    else:
        abv_avg_prices[price_point]=1
    # If the price is already a key in the dictionary
            # Add one to the count for that price point
            # YOUR CODE HERE
            
    # If the price has not been added to the dictionary
    # Else set the price as the key and the value as the integer `1`
    # YOUR CODE HERE

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(abv_avg_prices) == dict
assert len(abv_avg_prices) == 5
assert '\\$\\$\\$\\$' in abv_avg_prices

# %% [markdown]
# **Now reapply the same process, but instead calculate the price point frequencies for the `below_average` dataset.**

# %%
# Create an empty dictionary to store the
# counts for each price point
# YOUR CODE HERE
blw_avg_prices= dict()
# Loop over the below average restaurants
# YOUR CODE HERE
for key in below_average:
    # Isolate the price point for the restuarant
    # YOUR CODE HERE
    price_point=key['price']  
    # Check if the price has been added to the dictionary
    # YOUR CODE HERE
    if price_point in blw_avg_prices:
        blw_avg_prices[price_point]+=1
    else:
        blw_avg_prices[price_point]=1
            # If the price is already a key in the dictionary
            # Add one to the count for that price point
            # YOUR CODE HERE
            
    # If the price has not been added to the dictionary
    # Set the price as the key and the value as the integer `1`
    # YOUR CODE HERE

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(blw_avg_prices) == dict
assert len(blw_avg_prices) == 4
assert '\\$' in blw_avg_prices

# %% [markdown]
# ## Create a bar plot that sets the frequency of each price point as the y axis

# %%
# Create a matplotlib subplot with 1 row and 2 columns
# YOUR CODE HERE
fig, (ax1, ax2) = plt.subplots(1,2)

# Isolate keys of the below average price count dictionary
# This will be the x-axis
# YOUR CODE HERE
x=blw_avg_prices.keys()
# Isolate the values of the below average price count dictionary
# This will be the y-axis
# YOUR CODE HERE
y=blw_avg_prices.values()
# Plot the below average price point counts as a bar plot
# on the first axis
# YOUR CODE HERE
ax1.plot(x,y)
# Set the title for the first axis
# to the string "Below Average"
# YOUR CODE HERE
ax1.title.set_text('Below Average')
# Isolate keys of the above average price count dictionary
# This will be the x-axis
# YOUR CODE HERE
x1=abv_avg_prices.keys()
# Isolate the values of the above average price count dictionary
# This will be the y-axis
# YOUR CODE HERE
y1=abv_avg_prices.values()
# Plot the above average price counts as a bar plot
# on the second axis
# YOUR CODE HERE
ax2.plot(x1,y1)
# Set the title for the second axis to 
# the string 'Above Average'
# YOUR CODE HERE
ax2.title.set_text('Above Average')

# %% [markdown]
# **Interpret the above visualization. How does it relate to your client's claims?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Analyze restaurant location
#
# In the cell below, use the `isolate_values` function to isolate `longitude` and `latitude` for above and below average restaurants.

# %%
# Replace None with your code
# Isolate longitude for above average restaurants
abv_avg_lon = isolate_values(dictionaries=above_average, key = 'longitude')

# Isolate latitude for above average restaurants
abv_avg_lat = isolate_values(dictionaries=above_average, key = 'latitude')

# Isolate longitude for below average restaurants
blw_avg_lon = isolate_values(dictionaries=below_average, key = 'longitude')

# Isolate latitude for below average restaurants
blw_avg_lat =isolate_values(dictionaries=below_average, key = 'latitude')

plt.figure(figsize=(15,6))
plt.scatter(abv_avg_lon, abv_avg_lat, label='Above')
plt.scatter(blw_avg_lon, blw_avg_lat, label='Below')
plt.legend();

# %% [markdown]
# ## Remove the outlier
#
# There is one restaurant in the above average dataset with a location dramatically west and south of all other observations. Let's remove that restaurant from the above average dataset and regenerate the scatter plot.

# %%
# Create an empty list
# that will contain data with
# the outlier removed
no_outliers =[] # YOUR CODE HERe

# Create an empty list to append the outlier
outlier = []# YOUR CODE HERE

# Loop over every restaurant in the above average dataset
# YOUR CODE HERE
for key in above_average:
    # Isolate the restaurant's longitude
    long= key['longitude']
    # YOUR CODE HERE
       # Check if the longitude value is greater than the integer -90
    # YOUR CODE HERE
    if long > -90:
        # Append the restaurant to the no_outliers list
        # YOUR CODE HERE
        no_outliers.append(key)
    # If longitude is less than -90 it is an outlier
    # and should be appended to the outlier list
    # YOUR CODE HERE
    else:
        outlier.append(key)

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(no_outliers) == list
assert type(outlier) == list
assert len(no_outliers) == len(above_average) - 1
assert len(outlier) == 1

# %% [markdown]
# Now regenerate the longitude and latitude for above average restaurants using the `no_outliers` dataset, and regenerate the scatter plot!

# %%
abv_avg_lon = isolate_values(dictionaries= no_outliers, key = 'longitude')
abv_avg_lat = isolate_values(dictionaries= no_outliers, key = 'latitude')

plt.figure(figsize=(15,6))
plt.scatter(abv_avg_lon, abv_avg_lat, label='Above')
plt.scatter(blw_avg_lon, blw_avg_lat, label='Below')
plt.legend();

# %% [markdown]
# Nice. This is much more interesting.

# %% [markdown]
# ## Plot the distribution of latitude and longitude
#
# To get a better sense about how latitude and longitude are working, in the cell below plot histograms for latitude and longitude.

# %%
# Create a matplotlib subplot with 1 row and 2 columns
# YOUR CODE HERE
fig, ax = plt.subplots(1, 2)
# Plot a histogram of above average longitude
# on the first subplot axis. Set alpha to .6
# Set label to the string "Above"
# YOUR CODE HERE
ax[0].hist(abv_avg_lon, alpha = 0.6)
# Plot a histogram of below average longitude
# on the first subplot axis. Set alpha to .6
# Set label to the string "Below"
# YOUR CODE HERE

# Set the title for the first subplot axis
# to the string "Longitude"
ax[0].set_title("longitude")


# Plot a histogram of above average latitude
# on the second subplot axis. Set alpha to .6
# Set label to the string "Above"
# YOUR CODE HERE
ax[1].hist(abv_avg_lat, alpha=0.6)
# Plot a histogram of below average latitude
# on the second subplot axis. Set alpha to .6
# Set label to the string "Below"
# YOUR CODE HERE

# Set the title for the second subplot axis
# to the string "Latitude"
# YOUR CODE HERE
ax[1].set_title("latitude")
# Out:
# Text(0.5, 1.0, 'latitude')

# %% [markdown]
# **Interpret the above visualization. How does it relate to your client's claims?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Find the most common zipcode for above average restaurants
#
# In the cell below, loop over the restaurants in the above average dataset and count the frequency of the restaurants zipcode.

# %%
# YOUR CODE HERE# Create an empty dictionary
# This dictionary will hold the counts
# for each zipcode
abv_avg_zip_cnts = dict() # YOUR CODE HERE

# Loop over the above average dataset
# YOUR CODE HERE
for key in above_average:   
    # Isolate the restaurant's zipcode 
    # YOUR CODE HERE
    zip=key['location'] ['zip_code']
    # Check if the zipcode is a key in the dictionary
    # YOUR CODE HERE
    if zip in abv_avg_zip_cnts:   
        # Add one to the zipcode's value
        # YOUR CODE HERE
        abv_avg_zip_cnts[zip]+=1
    # If the zipcode is not a key
    # add it to the dictionary with a value of 1
    # YOUR CODE HERE
    else:
        abv_avg_zip_cnts[zip]=1

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(abv_avg_zip_cnts) == dict
assert len(abv_avg_zip_cnts) == 104 or len(abv_avg_zip_cnts) == 103
assert '10012' in abv_avg_zip_cnts

# %% [markdown]
# Now loop over the `abv_avg_zip_cnts` dictionary and find the zipcode with the largest count.
#
# For this question, there are multiple ways to find the solution. Comments have not been provided.

# %%
    greatest = 0
for key, value  in abv_avg_zip_cnts.items():
    
    if key,value <= greatest
# Out:
#   File "/tmp/ipykernel_66/4170115664.py", line 4
#     if key,value <= greatest
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# **Interpret the results. How does the most frequent zipcode relate to your client's claims?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Compile your findings into a report
#
# You have address all of your client's claims! In the cell below, describe the findings of your analysis.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# # Summary
#
# Well done! As you can see, manipulating nested data stuctures can be a challenging task. Pulling information from json objects requires a thoughtful inspection of how the data is organized, and code that allows you to avoid repetition.
